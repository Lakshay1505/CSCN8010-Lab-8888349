# %% [markdown]
# # **LAB - 3**

# %% [markdown]
# Student Id - 8888349
#
# Name - Lakshay Soni
#
# Goal - Building model using 3 different variables for predecting the price of house in California with using certain Parameters

# %% [markdown]
# Basic Data Analytics

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df_LS = pd.read_csv ("/Users/lakshay/Desktop/ML_Course/FINAL_GIT/CSCN8010-Lab-8888349/Data/housing.csv")  # Reading csv file 
df_LS.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# The describe function gives so many insights for certain variables.

# %% [markdown]
# 1. **Making Model of Linear Regression** using Median Income to predict Value of House

# %%
MIncome_1 = df_LS[["median_income"]]  # Extracting features for the both of the model of median income and value's of the house.
M_H_Value = df_LS[["median_house_value"]]
LS_Model = LinearRegression() # Creating a Linear Regression model

# %%
plt.figure(figsize=(100,100))
sns.relplot(x = "median_income", y = "median_house_value", data=df_LS) # plotting in a graph
plt.title('Median of Income and House') # title for the graph
plt.show()

# %%
# X_train, x_test, y_train, Y_test = train_test_split(X,y, test_size=0.3)
LS_Model.fit(X = MIncome_1, y = M_H_Value) # Training the Model
# Out:
# LinearRegression()

# %%
LS_E_1 = np.array(np.random.uniform(0, 18, 100)).reshape(-1, 1)
LS_P_1 = LS_Model.predict(LS_E_1) # Evaluating the model
# Out:
# /Users/lakshay/venv/CSCN8010_classic_ml/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(90,90))
sns.relplot(x = "median_income", y = "median_house_value", data=df)
plt.plot(LS_E_1, LS_P_1, color='Green', linewidth=2)
plt.title('Income-Housing Relationship')


plt.show()

# %%
print(LS_Model.intercept_)
print(LS_Model.coef_[0])

# printing the co-effeceint And intercept value
# Out:
# [45085.57670327]
# [41793.8492019]

# %%
# Depecting an part of cap data which showing the income and house value at the same point.
# There is a positive link between ' median_income' and 'median_house_value'; as 'median_income' increases, the model predicts that 'median_house_value' will similarly increase.
# Outliers could be extreme values, such as the maximum'median_house_value'.

# %% [markdown]
# 2. **Using population and median income.**

# %%
LS_2 = df_LS[["population"]]
LSS_2 = df_LS[["median_house_value"]]
LS_Model_2 = LinearRegression() # Creating a Linear Regression model

# %%
plt.figure(figsize=(90,90))
sns.relplot(x = "population", y = "median_house_value", data=df_LS)
plt.title('population-income dynamic') #  labelling the below table
plt.show()

# %%
LS_Model_2.fit(X = LS_2, y = LSS_2) # Training the model
# Out:
# LinearRegression()

# %%
LS_2 = np.array(np.random.uniform(10, 40000, 100)).reshape(-1, 1)
LSS_2 = LS_Model_2.predict(LS_2) # Making predictions 
plt.show
# Out:
# /Users/lakshay/venv/CSCN8010_classic_ml/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(90,90))
sns.relplot(x = "population", y = "median_house_value", data=df_LS)  # creating a scatter plot

plt.plot(LS_2, LSS_2, color='Green', linewidth=4) # Plotting linear regression line
plt.title('population-housing correlation')

plt.show()

# %%
print(LS_Model_2.intercept_)
print(LS_Model_2.coef_[0])
# Out:
# [210436.26207627]
# [-2.51175277]

# %%
# The model often predicts a rise in median income when the population grows, according to a positive coefficient.
# value is suggesting that median value would be 200000 even though population is 0.
# A negative coefficient indicates that the model predicts a negative impact on median income as the population grows.

# %% [markdown]
# 3.  **Using *no_of_house_holds* and *median income**.

# %%
LS_3 = df_LS[["households"]] 
LSS_3 = df_LS[["median_house_value"]]
LS_Model_3 = LinearRegression() # Creating a Linear Regression model

# %%
plt.figure(figsize=(90,90))
sns.relplot(x = "households", y = "median_house_value", data=df_LS)
plt.title('Households and median Income')
plt.show()

# %%
LS_Model_3.fit(X = LS_3, y = LSS_3)
# Out:
# LinearRegression()

# %%
LS_3 = np.array(np.random.uniform(0, 8000, 100)).reshape(-1, 1)
LSS_3 = LS_Model_3.predict(LS_3)
# Out:
# /Users/lakshay/venv/CSCN8010_classic_ml/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(90,90))
sns.relplot(x = "households", y = "median_house_value", data=df_LS)
plt.plot(LS_3, LSS_3, color='Green', linewidth=4)
plt.title('Relationship between households and Median House Value')

plt.show()

# %%
# On avaerage there are 1000 households in each block of california.
# If we use household parameter for prediction it might have 90k mean absolute error i.e if we predict price of the house  based on households it might have variation of
#  more than 90000 between actual and predected price.

# %%
print(LS_Model_3.intercept_)
print(LS_Model_3.coef_[0]) # printing the Coeff and intercept value
# Out:
# [196928.57716233]
# [19.87277516]

# %% [markdown]
# # Description of 4 Variables using in this lab:

# %% [markdown]
# # Summarize in a table, for each of the three models:
#
# intercept and slope (0.5 point)
#
# Mean Squared Error - the loss (0.3 point)
#
# Mean Absolute Error (0.3 point)

# %% [markdown]
# # * For Median house value and Median income *

# %%
print(f"Mean squared error: {mean_squared_error(df_LS[['median_house_value']], LS_Model.predict(df_LS[['median_income']]))}")
print(f"Mean absolute error: {mean_absolute_error(df_LS[['median_house_value']], LS_Model.predict(df_LS[['median_income']]))}")
# Out:
# Mean squared error: 7011311502.929527
# Mean absolute error: 62625.9337911434

# %% [markdown]
# # * For Median house value and population*

# %%
print(f"Mean squared error: {mean_squared_error(df_LS[['median_house_value']], LS_Model_2.predict(df_LS[['population']]))}")
print(f"Mean absolute error: {mean_absolute_error(df_LS[['median_house_value']], LS_Model_2.predict(df_LS[['population']]))}")
# Out:
# Mean squared error: 13307412412.389355
# Mean absolute error: 91153.8200947318

# %% [markdown]
# # * For median house value and and households*

# %%
print(f"Mean squared error: {mean_squared_error(df_LS[['median_house_value']], LS_Model_3.predict(df_LS[['households']]))}")
print(f"Mean absolute error: {mean_absolute_error(df_LS[['median_house_value']], LS_Model_3.predict(df_LS[['households']]))}")
# Out:
# Mean squared error: 13257776904.728533
# Mean absolute error: 90802.74324318446

# %% [markdown]
# | Model        | Mean Squared Error (MSE) | Mean Absolute Error (MAE) |
# |--------------|--------------------------|---------------------------|
# | Model 1(median_income)      | 7011311502.93            | 62625.93                  |
# | Model 2(population)      | 13307412412.39           | 91153.82                  |
# | Model 3(households)      | 13257776904.73           | 90802.74                  |
